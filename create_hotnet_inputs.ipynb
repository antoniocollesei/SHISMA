# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## create scores

# %%
df = pd.read_csv("shap_values/shap_values_CIK_cells_pvalpenalized.csv")
df = df.abs()
genes = df.columns

for i in range(len(df)):
  row = df.iloc[i]
  if row.sum() != 0:
    row.T.to_csv(f"hierarchical-hotnet-python3-fixed/examples/shapelet_data/scores_{i}.tsv", header=False, sep="\t")

# %% [markdown]
# ## create edges

# %%
# Create a gene-index file
gene2index = pd.Series(index=genes, data=range(1, len(genes) + 1))


# Load edges
edges = pd.read_csv("string_interactions_short.tsv", sep="\t")
network_name = "string"

# Keep edges that are in genes
edges = edges[edges['node1'].isin(genes) & edges['node2'].isin(genes)]

#edges[['node1', 'node2']].to_csv("hierarchical-hotnet-python3-fixed/examples/shapelet_data/" + network_name, header=False, sep="\t", index=False)

# Map genes to indexes
edges['node1'] = edges['node1'].map(gene2index)
edges['node2'] = edges['node2'].map(gene2index)

# Print to csv only node1, node2
edges[['node1', 'node2']].to_csv("hierarchical-hotnet-python3-fixed/examples/shapelet_data/" + network_name + "_edge_list.tsv", header=False, sep="\t", index=False)

index2gene = pd.Series(data=genes, index=range(1, len(genes) + 1))
index2gene.to_csv("hierarchical-hotnet-python3-fixed/examples/shapelet_data/" + network_name + "_index_gene.tsv", header=False, sep="\t")
